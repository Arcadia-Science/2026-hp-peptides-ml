# %% [markdown]
# # Data-gen pipeline: SMILES → torch_geometric Data
#
# This notebook builds a full `torch_geometric.data.Data` object using the pipeline.
# Provide DeepMD models (pot/dipole/polar) or use Psi4 for small molecules.

# %%
from pathlib import Path
import sys
import torch

root = Path.cwd()
if (root / "data-gen-pipeline").is_dir():
    pipe_dir = (root / "data-gen-pipeline").resolve()
elif root.name == "data-gen-pipeline":
    pipe_dir = root.resolve()
else:
    raise RuntimeError("Run this notebook from the repo root or data-gen-pipeline/")

sys.path.insert(0, str(pipe_dir))

import pipeline
from deepmd_backend import DeepMDDipoleBackend, DeepMDPolarBackend, DeepMDPotHessianBackend
from psi4_backend import Psi4HessianBackend

# %%
smiles = "C"
pot_model = pipe_dir / "checkpoints/dpa2_multi_Domains_Drug.pth"

# Set these if you have DeepMD dipole/polar models.
dipole_model = None
polar_model = None

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

cfg = pipeline.PipelineConfig(
    output_dir=Path("data/gen"),
    device=device,
    dft_atom_cutoff=20,
    graph_k=20,
    graph_clamp_min=0.5,
    graph_clamp_max=100.0,
    pos_step=1e-3,
    allow_missing_polar=True,
    allow_missing_dipole=True,
    psi4_fallback=True,
)

# %%
dipole_backend = (
    DeepMDDipoleBackend(device=device, model_path=str(dipole_model))
    if dipole_model
    else None
)
polar_backend = (
    DeepMDPolarBackend(device=device, model_path=str(polar_model))
    if polar_model
    else None
)

hessian_backend = DeepMDPotHessianBackend(
    device=device,
    model_path=str(pot_model),
)

psi4_backend = None
try:
    psi4_backend = Psi4HessianBackend(
        device=torch.device("cpu"),
        method=cfg.psi4_method,
        basis=cfg.psi4_basis,
        charge=cfg.psi4_charge,
        multiplicity=cfg.psi4_multiplicity,
        num_threads=cfg.psi4_threads,
        memory=cfg.psi4_memory,
        scf_type=cfg.psi4_scf_type,
        guess=cfg.psi4_guess,
        quiet=cfg.psi4_quiet,
    )
except Exception as exc:
    print("Psi4 not available:", exc)

if dipole_backend is None and psi4_backend is None and not cfg.allow_missing_dipole:
    raise RuntimeError("Provide a DeepMD dipole model or install Psi4 for small molecules, or set allow_missing_dipole=True.")
# Out:
# To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, DP_INTRA_OP_PARALLELISM_THREADS, and DP_INTER_OP_PARALLELISM_THREADS. See https://deepmd.rtfd.io/parallelism/ for more information.
# You can use the environment variable DP_INFER_BATCH_SIZE tocontrol the inference batch size (nframes * natoms). The default value is 1024.
# Psi4 not available: psi4 is required for Psi4HessianBackend

# %%
item = pipeline.SmilesItem(number=1, smile=smiles)
data = pipeline.build_data_from_smiles(
    item,
    cfg,
    dipole_backend,
    polar_backend,
    hessian_backend,
    psi4_backend,
)
data
# Out:
# Data(edge_index=[2, 20], pos=[5, 3], z=[5], number=1, smile='C', energy=[1, 1], dipole=[1, 3], npacharge=[5], polar=[1, 3, 3], quadrupole=[1, 3, 3], octapole=[1, 3, 3, 3], hyperpolar=[1, 3, 3, 3], Hi=[5, 3, 3], Hij=[20, 3, 3], dedipole=[5, 3, 3], depolar=[5, 3, 6], tran_dipole=[1, 10, 3], tran_energy=[1, 10])

# %% [markdown]
# #### should see:
# ##### Data(edge_index=[2, 20], pos=[5, 3], number=1, smile='C', z=[5], quadrupole=[1, 3, 3], octapole=[1, 3, 3, 3], npacharge=[5], dipole=[1, 3], polar=[1, 3, 3], hyperpolar=[1, 3, 3, 3], energy=[1, 1], Hij=[20, 3, 3], Hi=[5, 3, 3], dedipole=[5, 3, 3], depolar=[5, 3, 6], tran_dipole=[1, 10, 3], tran_energy=[1, 10])

# %%
def shape(val):
    try:
        return tuple(val.shape)
    except Exception:
        return None

for key in data.keys():
    print(f"{key}: {shape(getattr(data, key))}")
# Out:
# energy: (1, 1)
# edge_index: (2, 20)
# tran_dipole: (1, 10, 3)
# tran_energy: (1, 10)
# octapole: (1, 3, 3, 3)
# z: (5,)
# polar: (1, 3, 3)
# Hi: (5, 3, 3)
# dedipole: (5, 3, 3)
# smile: None
# dipole: (1, 3)
# number: None
# depolar: (5, 3, 6)
# quadrupole: (1, 3, 3)
# pos: (5, 3)
# hyperpolar: (1, 3, 3, 3)
# Hij: (20, 3, 3)
# npacharge: (5,)

# %% [markdown]
# ### Sanity Testing

# %%
dataset=torch.load('../capsule-3259363/data/qm9s.pt', weights_only=False)

# %%
len(dataset)
# Out:
# 129817

# %%
import numpy as np
sample_size = 1000  # reduce for quicker debugging
to_check = np.random.choice(len(dataset), size=sample_size, replace=False)

# %%
from collections import defaultdict
from torchmetrics.functional import mean_absolute_error

error_dict = defaultdict(list)

shape_error = 0

for t in to_check:
    d = dataset[t]
    smile_is = d.smile
    item = pipeline.SmilesItem(number=1, smile=smile_is, pos=d.pos, z=d.z, edge_index=d.edge_index)
    prediction_from_backend = pipeline.build_data_from_smiles(item, cfg, dipole_backend, polar_backend, hessian_backend,psi4_backend)
    for key in d.keys():
        if key == "smile" or key == "number":
            continue
        try:
            diff = mean_absolute_error(getattr(d, key), getattr(prediction_from_backend, key)).item()
            error_dict[key].append(diff)
        except Exception as e:
            print(f"Error computing error for key {key}: {e}")
            shape_error += 1

print(f'shape errors: {shape_error} ; fraction: {shape_error/(len(to_check)*(len(d.keys())-2))}')
print(error_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#      10 smile_is = d.smile
#      11 item = pipeline.SmilesItem(number=1, smile=smile_is, pos=d.pos, z=d.z, edge_index=d.edge_index)
# ---> 12 prediction_from_backend = pipeline.build_data_from_smiles(item, cfg, dipole_backend, polar_backend, hessian_backend,psi4_backend)
#      13 for key in d.keys():
#      14     if key == "smile" or key == "number":
#
# File ~/Desktop/proteins-ml-copy/data-gen-pipeline/pipeline.py:539, in build_data_from_smiles(item, cfg, dipole_backend, polar_backend, hessian_backend, psi4_backend)
#     537         Hi, Hij = psi4_backend.compute(pos, z, edge_index)
#     538     else:
# --> 539         Hi, Hij = hessian_backend.compute(pos, z, edge_index)
#     540 except Exception:
#     541     if hessian_backend is None:
#
# File ~/Desktop/proteins-ml-copy/data-gen-pipeline/deepmd_backend.py:363, in DeepMDPotHessianBackend.compute(self, pos, z, edge_index)
#     360 def compute(
#     361     self, pos: torch.Tensor, z: torch.Tensor, edge_index: torch.Tensor
#     362 ) -> tuple[torch.Tensor, torch.Tensor]:
# --> 363     return self.fd.compute(pos, z, edge_index)
#
# File ~/Desktop/proteins-ml-copy/data-gen-pipeline/backends.py:54, in FiniteDifferenceHessianBackend.compute(self, pos, z, edge_index)
#      52 delta = torch.zeros_like(pos)
#      53 delta[i, a] = step
# ---> 54 f_plus = self.force_backend.forces(pos + delta, z)
#      55 f_minus = self.force_backend.forces(pos - delta, z)
#      56 deriv = -(f_plus - f_minus) / (2.0 * step)
#
# File ~/Desktop/proteins-ml-copy/data-gen-pipeline/deepmd_backend.py:327, in DeepMDPotBackend.forces(self, pos, z)
#     326 def forces(self, pos: torch.Tensor, z: torch.Tensor) -> torch.Tensor:
# --> 327     out = self._call(pos, z, atomic=False, head=self.head)
#     328     _, forces, _, _, _ = self._parse_eval(out, pos)
#     329     forces_t = self._as_tensor(forces, pos)
#
# File ~/Desktop/proteins-ml-copy/data-gen-pipeline/deepmd_backend.py:201, in DeepMDBase._call(self, pos, z, atomic, **kwargs)
#     198 atype = self._atype_from_z(z).detach().cpu().numpy().astype(np.int32)
#     200 if hasattr(self._model, "eval"):
# --> 201     out = self._model.eval(coords, cells, atype, atomic=atomic, **kwargs)
#     202 else:
#     203     out = self._model(coords, cells, atype)
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/infer/deep_pot.py:208, in DeepPot.eval(self, coords, cells, atom_types, atomic, fparam, aparam, mixed_type, **kwargs)
#     192 # This method has been used by:
#     193 # documentation python.md
#     194 # dp model_devi: +fparam, +aparam, +mixed_type
#    (...)    197 # dpdata
#     198 # ase
#     199 (
#     200     coords,
#     201     cells,
#    (...)    206     natoms,
#     207 ) = self._standard_input(coords, cells, atom_types, fparam, aparam, mixed_type)
# --> 208 results = self.deep_eval.eval(
#     209     coords,
#     210     cells,
#     211     atom_types,
#     212     atomic,
#     213     fparam=fparam,
#     214     aparam=aparam,
#     215     **kwargs,
#     216 )
#     217 energy = results["energy_redu"].reshape(nframes, 1)
#     218 force = results["energy_derv_r"].reshape(nframes, natoms, 3)
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/pt/infer/deep_eval.py:362, in DeepEval.eval(self, coords, cells, atom_types, atomic, fparam, aparam, **kwargs)
#     360 request_defs = self._get_request_defs(atomic)
#     361 if "spin" not in kwargs or kwargs["spin"] is None:
# --> 362     out = self._eval_func(self._eval_model, numb_test, natoms)(
#     363         coords, cells, atom_types, fparam, aparam, request_defs
#     364     )
#     365 else:
#     366     out = self._eval_func(self._eval_model_spin, numb_test, natoms)(
#     367         coords,
#     368         cells,
#    (...)    373         request_defs,
#     374     )
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/pt/infer/deep_eval.py:442, in DeepEval._eval_func.<locals>.eval_func(*args, **kwargs)
#     441 def eval_func(*args: Any, **kwargs: Any) -> Any:
# --> 442     return self.auto_batch_size.execute_all(
#     443         inner_func, numb_test, natoms, *args, **kwargs
#     444     )
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/utils/batch_size.py:208, in AutoBatchSize.execute_all(self, callable, total_size, natoms, *args, **kwargs)
#     206 returned_dict = None
#     207 while index < total_size:
# --> 208     n_batch, result = self.execute(execute_with_batch_size, index, natoms)
#     209     if n_batch == 0:
#     210         continue
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/utils/batch_size.py:109, in AutoBatchSize.execute(self, callable, start_index, natoms)
#     107     batch_nframes = self.current_batch_size
#     108 try:
# --> 109     n_batch, result = callable(max(batch_nframes, 1), start_index)
#     110 except Exception as e:
#     111     if not self.is_oom_error(e):
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/utils/batch_size.py:179, in AutoBatchSize.execute_all.<locals>.execute_with_batch_size(batch_size, start_index)
#     177 end_index = start_index + batch_size
#     178 end_index = min(end_index, total_size)
# --> 179 return (end_index - start_index), callable(
#     180     *[
#     181         (
#     182             vv[start_index:end_index, ...]
#     183             if (
#     184                 (array_api_compat.is_array_api_obj(vv) and vv.ndim > 1)
#     185                 or str(vv.__class__) == "<class 'paddle.Tensor'>"
#     186             )
#     187             else vv
#     188         )
#     189         for vv in args
#     190     ],
#     191     **{
#     192         kk: (
#     193             vv[start_index:end_index, ...]
#     194             if (
#     195                 (array_api_compat.is_array_api_obj(vv) and vv.ndim > 1)
#     196                 or str(vv.__class__) == "<class 'paddle.Tensor'>"
#     197             )
#     198             else vv
#     199         )
#     200         for kk, vv in kwargs.items()
#     201     },
#     202 )
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/pt/infer/deep_eval.py:519, in DeepEval._eval_model(self, coords, cells, atom_types, fparam, aparam, request_defs)
#     515     aparam_input = None
#     516 do_atomic_virial = any(
#     517     x.category == OutputVariableCategory.DERV_C for x in request_defs
#     518 )
# --> 519 batch_output = model(
#     520     coord_input,
#     521     type_input,
#     522     box=box_input,
#     523     do_atomic_virial=do_atomic_virial,
#     524     fparam=fparam_input,
#     525     aparam=aparam_input,
#     526 )
#     527 if isinstance(batch_output, tuple):
#     528     batch_output = batch_output[0]
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/deepmd/pt/train/wrapper.py:189, in ModelWrapper.forward(self, coord, atype, spin, box, cur_lr, label, task_key, inference_only, do_atomic_virial, fparam, aparam)
#     186     input_dict["spin"] = spin
#     188 if self.inference_only or inference_only:
# --> 189     model_pred = self.model[task_key](**input_dict)
#     190     return model_pred, None, None
#     191 else:
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/proteins-ml-copy/.venv2/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# KeyboardInterrupt:

# %%
len(error_dict)
# Out:
# 16

# %%
# !pip install -q seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
error_dict.keys()
# Out:
# dict_keys(['energy', 'edge_index', 'tran_dipole', 'tran_energy', 'octapole', 'z', 'polar', 'Hi', 'dedipole', 'dipole', 'depolar', 'quadrupole', 'pos', 'hyperpolar', 'Hij', 'npacharge'])

# %%
sns.set(style="whitegrid")
sns.catplot(error_dict, kind="box", height=6, aspect=2)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def _to_numpy(x):
    try:
        import torch
        if isinstance(x, torch.Tensor):
            return x.detach().cpu().numpy()
    except Exception:
        pass
    return np.asarray(x)

def _is_numeric(arr: np.ndarray) -> bool:
    return np.issubdtype(arr.dtype, np.number)

def _clean_1d(a: np.ndarray) -> np.ndarray:
    a = np.asarray(a, dtype=np.float64).ravel()
    a = a[np.isfinite(a)]
    return a

def _nice_xlim(x):
    if x.size == 0:
        return None
    lo, hi = np.quantile(x, [0.01, 0.99])
    if np.isclose(lo, hi):
        lo, hi = np.min(x), np.max(x)
    if np.isclose(lo, hi):
        return (lo - 1, hi + 1)
    pad = 0.05 * (hi - lo)
    return (lo - pad, hi + pad)

def _finish_ax(ax, title):
    ax.set_title(title, loc="left", fontsize=12, fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("Count")
    ax.grid(True, axis="y", alpha=0.25)
    for spine in ["top", "right", "left"]:
        ax.spines[spine].set_visible(False)

def plot_distributions_seaborn(
    data: dict,
    keys=None,
    bins=50,
    max_cols=4,
    kde=True,
    quantile_clip=True,   # avoids a single outlier nuking the axis
):
    # Global seaborn look
    sns.set_theme(
        style="whitegrid",
        context="talk",
        font_scale=0.9
    )
    sns.set_context("talk", rc={"axes.titlesize": 13, "axes.labelsize": 11})

    if keys is None:
        keys = list(data.keys())

    for k in keys:
        if k not in data:
            continue

        arr = _to_numpy(data[k])

        if arr.size == 0:
            print(f"[skip] {k}: empty")
            continue
        if not _is_numeric(arr):
            print(f"[skip] {k}: non-numeric dtype {arr.dtype}")
            continue

        # ---------- edge_index ----------
        if k == "edge_index":
            a = arr
            if a.ndim == 2 and a.shape[0] == 2:
                fig, axes = plt.subplots(1, 2, figsize=(12, 3.6), constrained_layout=True)
                for i, name in enumerate(["source", "target"]):
                    x = _clean_1d(a[i])
                    sns.histplot(x=x, bins=bins, kde=kde, stat="count",
                                 element="step", fill=True, alpha=0.55, ax=axes[i])
                    _finish_ax(axes[i], f"edge_index[{i}] • {name}")
                    if quantile_clip and x.size > 20:
                        axes[i].set_xlim(_nice_xlim(x))
                fig.suptitle("edge_index", x=0.01, ha="left", fontweight="bold")
                plt.show()
                continue

        # ---------- pos ----------
        if k == "pos":
            a = arr
            if a.ndim == 2 and a.shape[1] in (2, 3):
                d = a.shape[1]
                labels = ["x", "y", "z"][:d]
                fig, axes = plt.subplots(1, d, figsize=(4.2*d + 1.2, 3.6), constrained_layout=True)
                if d == 1:
                    axes = [axes]
                for i, lab in enumerate(labels):
                    x = _clean_1d(a[:, i])
                    sns.histplot(x=x, bins=bins, kde=kde,
                                 element="step", fill=True, alpha=0.55, ax=axes[i])
                    _finish_ax(axes[i], f"pos • {lab}")
                    if quantile_clip and x.size > 20:
                        axes[i].set_xlim(_nice_xlim(x))
                fig.suptitle("pos", x=0.01, ha="left", fontweight="bold")
                plt.show()

                # norm panel
                norm = np.linalg.norm(a.astype(np.float64), axis=1)
                norm = _clean_1d(norm)
                fig, ax = plt.subplots(1, 1, figsize=(8, 3.6), constrained_layout=True)
                sns.histplot(x=norm, bins=bins, kde=kde,
                             element="step", fill=True, alpha=0.55, ax=ax)
                _finish_ax(ax, "pos • norm")
                if quantile_clip and norm.size > 20:
                    ax.set_xlim(_nice_xlim(norm))
                plt.show()
                continue

        # ---------- general ----------
        a = arr

        # If (N, d) with small d, do small multiples
        if a.ndim == 2 and a.shape[1] <= max_cols and a.shape[0] > 1:
            d = a.shape[1]
            fig, axes = plt.subplots(1, d, figsize=(4.2*d + 1.2, 3.6), constrained_layout=True)
            if d == 1:
                axes = [axes]
            for i in range(d):
                x = _clean_1d(a[:, i])
                sns.histplot(x=x, bins=bins, kde=kde,
                             element="step", fill=True, alpha=0.55, ax=axes[i])
                _finish_ax(axes[i], f"{k} • [{i}]")
                if quantile_clip and x.size > 20:
                    axes[i].set_xlim(_nice_xlim(x))
            fig.suptitle(k, x=0.01, ha="left", fontweight="bold")
            plt.show()
            continue

        # Otherwise: single distribution (flatten)
        x = _clean_1d(a)
        if x.size == 0:
            print(f"[skip] {k}: no finite values")
            continue

        fig, ax = plt.subplots(1, 1, figsize=(8, 3.6), constrained_layout=True)
        sns.histplot(
            x=x,
            bins=bins,
            kde=kde,
            stat="count",
            element="step",
            fill=True,
            alpha=0.55,
            ax=ax,
        )
        _finish_ax(ax, k)
        if quantile_clip and x.size > 20:
            ax.set_xlim(_nice_xlim(x))
        plt.show()

# %%
keys = [
    "energy", "edge_index", "tran_dipole", "tran_energy", "octapole", "z", "polar",
    "Hi", "dedipole", "dipole", "depolar", "quadrupole", "pos", "hyperpolar",
    "Hij", "npacharge"
]

# %%
plot_distributions_seaborn(error_dict, keys=keys, bins=60, kde=True)
